# %%
# Arranco montando Drive para acceder a los archivos necesarios

root_path = 'drive/My Drive/Big Data/'
data_path = root_path + 'Dataset/'
my_path = root_path + 'TP1/'

from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# Importo emulador 

import sys
sys.path.append('/content/' + root_path)

from MRE import Job

# %%
# Directorios
outputDir = my_path + 'output/'
inputDir1 = data_path + 'input/Enero/'
inputDir2 = data_path + 'input/Mayo/'
intersectgDir = outputDir + 'intersect/'

# %%
def fmap(key, value, context):
    context.write(value, 1)

# %%
def fmap2(key, value, context):
    context.write(value, 2)

# %%
def fred(key, values, context):
    sets = set()
    for value in values:
        sets.add(value)
        if len(sets) == 2: 
            context.write(key, 1)
            break

# %%
job = Job(inputDir1, intersectDir, fmap, fred)
job.addInputPath(inputDir2, fmap2)
success = job.waitForCompletion()

# %%
print(success)
# Out:
# True
